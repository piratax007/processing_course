// %% [markdown]
// # Flujo de un sketch
//
// Existen dos estándares de programación en processing.
//
// ## Secuencial estático
//
// Todas las líneas de código se ejecutan en estricto orden de forma secuencial desde la primera hasta la última, luego de ejecutar la última línea de código se detiene la ejecución.

// %%
size(250, 250); // determina el tamaño del lienzo

background(#57596D); // asigna el color del lienzo
fill(millis() % 255); // asigna el color de relleno
noStroke(); // elimina el borde
rectMode(CENTER); // cambia la forma en la que se dibuja un rectángulo
rect(width / 2, height / 2, 75, 75, 10); // dibuja un rectángulo
// termina la ejecución
// Out:
// <div id="canvas_div_2">
//   <b>Sketch #2:</b><br/>
//   <canvas id="canvas_2"></canvas><br/>
// </div>
// <div id="controls_div_2">
//   <button id="run_button_2" onclick="startSketch('2');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_2" onclick="pauseSketch('2');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_2" onclick="setupSketch('2');">
//     setup()
//   </button>
//   <button id="draw_button_2" onclick="drawSketch('2');">
//     draw()
//   </button>
// </div>
// <b>Sketch #2 state:</b> <span id="state_2">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = 'size(250, 250); // determina el tamaño del lienzo\n\nbackground(#57596D); // asigna el color del lienzo\nfill(millis() % 255); // asigna el color de relleno\nnoStroke(); // elimina el borde\nrectMode(CENTER); // cambia la forma en la que se dibuja un rectángulo\nrect(width / 2, height / 2, 75, 75, 10); // dibuja un rectángulo\n// termina la ejecución';
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_2").innerHTML = e.toString();
//         document.getElementById("state_2").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_2", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_2").innerHTML = e.toString();
//             document.getElementById("state_2").style.color = "red";
//             processingInstance = new Processing("canvas_2", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_2").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_2").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("state_2").innerHTML = "Running...";
//                 document.getElementById("state_2").style.color = "green";
//             }
//             change_button(document.getElementById("run_button_2"), true);
//             change_button(document.getElementById("pause_button_2"), false);
//             change_button(document.getElementById("setup_button_2"),  true);
//             change_button(document.getElementById("draw_button_2"), true);
//         } else {
//             if (!has_error) {
//                 document.getElementById("state_2").innerHTML = "Done.";
//                 document.getElementById("state_2").style.color = "blue";
//             }

// %% [markdown]
// ## Secuencial dinámico
//
// Se denomina **Bloque de código:** a todo el código contenido entre `{}`.
//
// Un sketch secuencial dinámico se ejecuta en estricta secuencia ordenada desde la primera línea del código hasta la última, cuando se ha terminado la ejecución de la última línea del sketch vuelve a empezar la ejecución en la primera línea. Este bucle se ejecuta de manera indefinida.
//
// Un sketch dinámico de processing tiene dos bloques obligatorios y únicos - `setup()` y `draw()`. Obligatorios porque no puede ejecutarse el sketch si no están definidos los dos bloques y únicos porque cada sketch puede tener definido únicamente un bloque `setup()` y un bloque `draw()` a la vez.

// %%
void setup(){
  size(250, 250); 
}

void draw(){ // Este bloque se ejecuta 60 veces cada segundo
  background(#57596D); 
  fill(millis() % 255);
  noStroke(); 
  rectMode(CENTER); 
  rect(width / 2, height / 2, 75, 75, 10);
}
// Out:
// <div id="canvas_div_3">
//   <b>Sketch #3:</b><br/>
//   <canvas id="canvas_3"></canvas><br/>
// </div>
// <div id="controls_div_3">
//   <button id="run_button_3" onclick="startSketch('3');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_3" onclick="pauseSketch('3');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_3" onclick="setupSketch('3');">
//     setup()
//   </button>
//   <button id="draw_button_3" onclick="drawSketch('3');">
//     draw()
//   </button>
// </div>
// <b>Sketch #3 state:</b> <span id="state_3">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = 'void setup(){\n  size(250, 250); \n}\n\nvoid draw(){ // Este bloque se ejecuta 60 veces cada segundo\n  background(#57596D); \n  fill(millis() % 255);\n  noStroke(); \n  rectMode(CENTER); \n  rect(width / 2, height / 2, 75, 75, 10);\n}';
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_3").innerHTML = e.toString();
//         document.getElementById("state_3").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_3", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_3").innerHTML = e.toString();
//             document.getElementById("state_3").style.color = "red";
//             processingInstance = new Processing("canvas_3", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_3").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_3").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("state_3").innerHTML = "Running...";
//                 document.getElementById("state_3").style.color = "green";
//             }
//             change_button(document.getElementById("run_button_3"), true);
//             change_button(document.getElementById("pause_button_3"), false);
//             change_button(document.getElementById("setup_button_3"),  true);
//             change_button(document.getElementById("draw_button_3"), true);
//         } else {
//             if (!has_error) {
//                 document.getElementById("state_3").innerHTML = "Done.";
//                 document.getElementById("state_3").style.color = "blue";
//             }
//             change_button(document.getElementById("run_button_3"), true);
//             change_button(document.getElementById

// %% [markdown]
// ## Variables del sistema
//
// Processing define algunas variables que permiten interactuar directamente con valores definidos por el sistema, así por ejemplo `width` y `height` guardan respectivamente el ancho y alto del lienzo de tal forma que puedan utilizarse para controlar la posición de los objetos contenidos en el lienzo (ver el ejemplo anterior). Las variables `mouseX` y `mouseY` leen las coordenadas del puntero en tiempo real.

// %%
void setup(){
    size(350, 250);
    noStroke();
}

void draw(){
    background(#51BB58);
    fill(#FFA100);
    ellipse(width - mouseX, height - mouseY, 75, 75); // ¿dónde esta la elipse en cualquier momento?
}
// Out:
// <div id="canvas_div_4">
//   <b>Sketch #4:</b><br/>
//   <canvas id="canvas_4"></canvas><br/>
// </div>
// <div id="controls_div_4">
//   <button id="run_button_4" onclick="startSketch('4');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_4" onclick="pauseSketch('4');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_4" onclick="setupSketch('4');">
//     setup()
//   </button>
//   <button id="draw_button_4" onclick="drawSketch('4');">
//     draw()
//   </button>
// </div>
// <b>Sketch #4 state:</b> <span id="state_4">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = 'void setup(){\n    size(350, 250);\n    noStroke();\n}\n\nvoid draw(){\n    background(#51BB58);\n    fill(#FFA100);\n    ellipse(width - mouseX, height - mouseY, 75, 75); // ¿dónde esta la elipse en cualquier momento?\n}';
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_4").innerHTML = e.toString();
//         document.getElementById("state_4").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_4", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_4").innerHTML = e.toString();
//             document.getElementById("state_4").style.color = "red";
//             processingInstance = new Processing("canvas_4", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_4").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_4").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("state_4").innerHTML = "Running...";
//                 document.getElementById("state_4").style.color = "green";
//             }
//             change_button(document.getElementById("run_button_4"), true);
//             change_button(document.getElementById("pause_button_4"), false);
//             change_button(document.getElementById("setup_button_4"),  true);
//             change_button(document.getElementById("draw_button_4"), true);
//         } else {
//             if (!has_error) {
//                 document.getElementById("state_4").innerHTML = "Done.";
//                 document.getElementById("state_4").style.color = "blue";
//             }
//             change_button(document.getElementById("run_button_4"), true);
//             change_button(document.getElementById("pause_button

// %% [markdown]
// las varialbles `pmouseX` y `pmouseY` leen las coordenadas actuales del mouse, cuando el puntero cambia de posición almacenan las variables correspondiente a la última posición registrada.

// %%
void setup(){
    size(350, 250);
    strokeWeight(1);
    background(#393631);
    stroke(#FDF7ED);
}

void draw(){
    line(pmouseX, pmouseY, mouseX, mouseY);
}
// Out:
// <div id="canvas_div_5">
//   <b>Sketch #5:</b><br/>
//   <canvas id="canvas_5"></canvas><br/>
// </div>
// <div id="controls_div_5">
//   <button id="run_button_5" onclick="startSketch('5');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_5" onclick="pauseSketch('5');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_5" onclick="setupSketch('5');">
//     setup()
//   </button>
//   <button id="draw_button_5" onclick="drawSketch('5');">
//     draw()
//   </button>
// </div>
// <b>Sketch #5 state:</b> <span id="state_5">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = 'void setup(){\n    size(350, 250);\n    strokeWeight(1);\n    background(#393631);\n    stroke(#FDF7ED);\n}\n\nvoid draw(){\n    line(pmouseX, pmouseY, mouseX, mouseY);\n}';
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_5").innerHTML = e.toString();
//         document.getElementById("state_5").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_5", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_5").innerHTML = e.toString();
//             document.getElementById("state_5").style.color = "red";
//             processingInstance = new Processing("canvas_5", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_5").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_5").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("state_5").innerHTML = "Running...";
//                 document.getElementById("state_5").style.color = "green";
//             }
//             change_button(document.getElementById("run_button_5"), true);
//             change_button(document.getElementById("pause_button_5"), false);
//             change_button(document.getElementById("setup_button_5"),  true);
//             change_button(document.getElementById("draw_button_5"), true);
//         } else {
//             if (!has_error) {
//                 document.getElementById("state_5").innerHTML = "Done.";
//                 document.getElementById("state_5").style.color = "blue";
//             }
//             change_button(document.getElementById("run_button_5"), true);
//             change_button(document.getElementById("pause_button_5"), true);
//             change_button(document.ge

// %% [markdown]
// ## Mouse y Teclado
//
// La interacción con las aplicaciones es una condición necesaria si bien puede no ser fundamental. Esta interacción puede hacerse mediante los dispositivos de entrada (`input`) disponibles: panel táctil, mouse, teclado, etc. Processing cuenta con funciones y variables definidas para leer el estado de los dispositivos de entrada y determinar así comportamientos interativos.

// %%
void setup(){
    size(350, 250);
    strokeWeight(1);
    background(#393631);
    stroke(#FDF7ED);
}

void draw(){
    line(pmouseX, pmouseY, mouseX, mouseY);
}

void mousePressed(){ // al ser precionado algún botón del mouse se limpia el lienzo y cambia los colores de lienzo y línea
    background(#393631);
    stroke(#FDF7ED);
}

void keyPressed(){ // al presionar cualquier tecla se limpia el lienzo y cambia los colores de lienzo y línea
    background(#FDF7ED);
    stroke(#393631);
}
// Out:
// <div id="canvas_div_1">
//   <b>Sketch #1:</b><br/>
//   <canvas id="canvas_1"></canvas><br/>
// </div>
// <div id="controls_div_1">
//   <button id="run_button_1" onclick="startSketch('1');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_1" onclick="pauseSketch('1');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_1" onclick="setupSketch('1');">
//     setup()
//   </button>
//   <button id="draw_button_1" onclick="drawSketch('1');">
//     draw()
//   </button>
// </div>
// <b>Sketch #1 state:</b> <span id="state_1">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = 'void setup(){\n    size(350, 250);\n    strokeWeight(1);\n    background(#393631);\n    stroke(#FDF7ED);\n}\n\nvoid draw(){\n    line(pmouseX, pmouseY, mouseX, mouseY);\n}\n\nvoid mousePressed(){ // al ser precionado algún botón del mouse se limpia el lienzo y cambia los colores de lienzo y línea\n    background(#393631);\n    stroke(#FDF7ED);\n}\n\nvoid keyPressed(){ // al presionar cualquier tecla se limpia el lienzo y cambia los colores de lienzo y línea\n    background(#FDF7ED);\n    stroke(#393631);\n}';
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_1").innerHTML = e.toString();
//         document.getElementById("state_1").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_1", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_1").innerHTML = e.toString();
//             document.getElementById("state_1").style.color = "red";
//             processingInstance = new Processing("canvas_1", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_1").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_1").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("state_1").innerHTML = "Running...";
//                 document.getElementById("state_1").style.color = "green";
//             }
//             change_button(document.getElementById("run_button_1"), true);
//             change_button(document.getElementById("pause_button_1"), false);
//             change_button(document.getElementById("setup_button_1"),  true);
//             change_button(document.getElementById("draw_button_1"), true);
//         } else {
//             if (!has_error) {

// %% [markdown]
// ## Variables
//
// Las variables son lugares en memoria utilizados para almacenar datos que resultan del cálculo de alguna operación en medio de la ejecución del sketch. Así como las variables `mouseX` y `mouseY`, el desarrollador puede crear cuantas variables requiera.
//
// - **Declarar las variables:** Por convención el espacio para declarar variables se ubica antes del bloque `setup`. Las variables se declaran mediante la sintaxis `tipo nombre;` donde tipo puede ser `int` número entero, `float` número decimal, `double` número decimal largo, etc. Otros tipos de variables se estudiarán más adelante en este mismo curso.
//
// Al asignar nombre a una variable debe tenerse en cuenta que éste sea suficientemente descriptivo como para que el código sea entendible, sin embargo hay que tener en cuenta que el nombre de una variable - por convención - debe iniciar con letra minúscula y si se trata de un nombre compuesto (varias palabras) no se utilizarán espacios de separación y a partir de la segunda palabra, se escribirán con mayúscula inicial. Los nombres de variables deben iniciar con un caracter alfabético.
//
// - **Inicializar variables:** Después de declarar una variable se debe asignar un valor con el que se reserva el espacio en memoria dedicado a la variable. La inicialización de una variable puede hacerse en el mismo momento en el que se declara o en el bloque `setup`.

// %%
int diameter = 50; // dedeclara e inicializa la variable
    
void setup(){
    size(100, 100);
}

void draw(){
    background(#393631);
    fill(255);
    ellipse(width / 2, height / 2, diameter, diameter);
}
// Out:
// <div id="canvas_div_7">
//   <b>Sketch #7:</b><br/>
//   <canvas id="canvas_7"></canvas><br/>
// </div>
// <div id="controls_div_7">
//   <button id="run_button_7" onclick="startSketch('7');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_7" onclick="pauseSketch('7');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_7" onclick="setupSketch('7');">
//     setup()
//   </button>
//   <button id="draw_button_7" onclick="drawSketch('7');">
//     draw()
//   </button>
// </div>
// <b>Sketch #7 state:</b> <span id="state_7">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = 'int diameter = 50; // dedeclara e inicializa la variable\n    \nvoid setup(){\n    size(100, 100);\n}\n\nvoid draw(){\n    background(#393631);\n    fill(255);\n    ellipse(width / 2, height / 2, diameter, diameter);\n}';
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_7").innerHTML = e.toString();
//         document.getElementById("state_7").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_7", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_7").innerHTML = e.toString();
//             document.getElementById("state_7").style.color = "red";
//             processingInstance = new Processing("canvas_7", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_7").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_7").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("state_7").innerHTML = "Running...";
//                 document.getElementById("state_7").style.color = "green";
//             }
//             change_button(document.getElementById("run_button_7"), true);
//             change_button(document.getElementById("pause_button_7"), false);
//             change_button(document.getElementById("setup_button_7"),  true);
//             change_button(document.getElementById("draw_button_7"), true);
//         } else {
//             if (!has_error) {
//                 document.getElementById("state_7").innerHTML = "Done.";
//                 document.getElementById("state_7").style.color = "blue";
//             }
//             change_button(document.getElementById("run_button_7"), true);
//             change_button(document.getElementById("pause_button_7

// %%
int diameter; // declara la variable
    
void setup(){
    size(100, 100);
    diameter = 50; // inicializa la variable
}

void draw(){
    background(#393631);
    ellipse(width / 2, height / 2, diameter, diameter);
}
// Out:
// <div id="canvas_div_8">
//   <b>Sketch #8:</b><br/>
//   <canvas id="canvas_8"></canvas><br/>
// </div>
// <div id="controls_div_8">
//   <button id="run_button_8" onclick="startSketch('8');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_8" onclick="pauseSketch('8');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_8" onclick="setupSketch('8');">
//     setup()
//   </button>
//   <button id="draw_button_8" onclick="drawSketch('8');">
//     draw()
//   </button>
// </div>
// <b>Sketch #8 state:</b> <span id="state_8">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = 'int diameter; // declara la variable\n    \nvoid setup(){\n    size(100, 100);\n    diameter = 50; // inicializa la variable\n}\n\nvoid draw(){\n    background(#393631);\n    ellipse(width / 2, height / 2, diameter, diameter);\n}';
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_8").innerHTML = e.toString();
//         document.getElementById("state_8").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_8", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_8").innerHTML = e.toString();
//             document.getElementById("state_8").style.color = "red";
//             processingInstance = new Processing("canvas_8", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_8").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_8").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("state_8").innerHTML = "Running...";
//                 document.getElementById("state_8").style.color = "green";
//             }
//             change_button(document.getElementById("run_button_8"), true);
//             change_button(document.getElementById("pause_button_8"), false);
//             change_button(document.getElementById("setup_button_8"),  true);
//             change_button(document.getElementById("draw_button_8"), true);
//         } else {
//             if (!has_error) {
//                 document.getElementById("state_8").innerHTML = "Done.";
//                 document.getElementById("state_8").style.color = "blue";
//             }
//             change_button(document.getElementById("run_button_8"), true);
//             change_button(document.getElementById("paus

// %% [markdown]
// - **Utilizar la variable:** Como en los sketch de ejemplo anteriores, una variable puede utilizarse para asignar valores repetitivos a partes del sketch, así por ejemplo se ha utilizado la variable `diameter` para establecer la longitud del diámetro horizontal y vertical en la elipse construida, de esta forma, si se requiere modificar este diámetro no hará falta cambiar dos valores sino únicamente el valor de inicialización de la variable.

// %% [markdown]
// ### Modificando el valor de una variable
//
// El valor asignado a una variable puede modificarse en medio de la ejecución del sketch de acuerdo a como convenga, una de las formas más utilizadas es el incrementar constantemente el valor lo cual puede hacerse con cualquiera de estas formas sintacticas equivalentes
//
// `variable = variable + incremento`
//
// o
//
// `variable += incremento`
//
// Estas dos formas incrementales agregan al valor de la variable el ``incremento`` dado, reemplazando el valor original con el nuevo valor calculado.
//
// Cuando `incremento` es igual a uno (1) puede utilizarse la sintaxis `variable++`.
//
// Estas formas sintacticas de incremento puede utilizarse tanto con valores positivos como negativos.
//
// `variable = variable - incremento`
//
// o
//
// `variable -= incremento`
//
// o
//
// `variable--`
//
// En el siguiente ejemplo se utiliza la variable `x` incrementada en 1 en cada ejecución del bloque `draw` para simular el desplazamiento horizontal de la elipse. La secuencia ejecutada en el bloque `draw` es
//
// - pinta el lienzo.
// - dibuja la elipse en posición x (inicia en 25) y (la mitad de la altura del lienzo).
// - aumenta `x` en 1.
// - reinicia la ejecución.
//
// Esta secuencia se ejecuta 60 veces en un segundo (el `framerate` por defecto).

// %%
int x = 25; 
    
void setup(){
    size(800, 100);
}

void draw(){
    background(#393631);
    ellipse(x, height / 2, 50, 50);
    x++; // incrementa el valor de x en 1
}
// Out:
// <div id="canvas_div_9">
//   <b>Sketch #9:</b><br/>
//   <canvas id="canvas_9"></canvas><br/>
// </div>
// <div id="controls_div_9">
//   <button id="run_button_9" onclick="startSketch('9');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_9" onclick="pauseSketch('9');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_9" onclick="setupSketch('9');">
//     setup()
//   </button>
//   <button id="draw_button_9" onclick="drawSketch('9');">
//     draw()
//   </button>
// </div>
// <b>Sketch #9 state:</b> <span id="state_9">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = 'int x = 25; \n    \nvoid setup(){\n    size(800, 100);\n}\n\nvoid draw(){\n    background(#393631);\n    ellipse(x, height / 2, 50, 50);\n    x++; // incrementa el valor de x en 1\n}';
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_9").innerHTML = e.toString();
//         document.getElementById("state_9").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_9", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_9").innerHTML = e.toString();
//             document.getElementById("state_9").style.color = "red";
//             processingInstance = new Processing("canvas_9", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_9").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_9").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("state_9").innerHTML = "Running...";
//                 document.getElementById("state_9").style.color = "green";
//             }
//             change_button(document.getElementById("run_button_9"), true);
//             change_button(document.getElementById("pause_button_9"), false);
//             change_button(document.getElementById("setup_button_9"),  true);
//             change_button(document.getElementById("draw_button_9"), true);
//         } else {
//             if (!has_error) {
//                 document.getElementById("state_9").innerHTML = "Done.";
//                 document.getElementById("state_9").style.color = "blue";
//             }
//             change_button(document.getElementById("run_button_9"), true);
//             change_button(document.getElementById("pause_button_9"), true);
//             change_button(

// %% [markdown]
// #### número aleatorios
// La función `random(h)` o `random(l, h)` devuelve un número decimal aleatorio entre 0 y `h` (en su primera forma) o entre `l` y `h`. Si se quiere convertir un número aleatorio generado con `random()` a entero puede usarse la función `int(random())`.

// %%
int x, y;

void setup(){
    size(500, 300);
    background(#393631);
}

void draw(){
    x = int(random(width));
    y = int(random(height));
    ellipse(random(width), random(height), 25, 25);
}
// Out:
// <div id="canvas_div_10">
//   <b>Sketch #10:</b><br/>
//   <canvas id="canvas_10"></canvas><br/>
// </div>
// <div id="controls_div_10">
//   <button id="run_button_10" onclick="startSketch('10');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_10" onclick="pauseSketch('10');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_10" onclick="setupSketch('10');">
//     setup()
//   </button>
//   <button id="draw_button_10" onclick="drawSketch('10');">
//     draw()
//   </button>
// </div>
// <b>Sketch #10 state:</b> <span id="state_10">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = 'int x, y;\n\nvoid setup(){\n    size(500, 300);\n    background(#393631);\n}\n\nvoid draw(){\n    x = int(random(width));\n    y = int(random(height));\n    ellipse(random(width), random(height), 25, 25);\n}';
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_10").innerHTML = e.toString();
//         document.getElementById("state_10").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_10", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_10").innerHTML = e.toString();
//             document.getElementById("state_10").style.color = "red";
//             processingInstance = new Processing("canvas_10", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_10").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_10").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("state_10").innerHTML = "Running...";
//                 document.getElementById("state_10").style.color = "green";
//             }
//             change_button(document.getElementById("run_button_10"), true);
//             change_button(document.getElementById("pause_button_10"), false);
//             change_button(document.getElementById("setup_button_10"),  true);
//             change_button(document.getElementById("draw_button_10"), true);
//         } else {
//             if (!has_error) {
//                 document.getElementById("state_10").innerHTML = "Done.";
//                 document.getElementById("state_10").style.color = "blue";
//             }
//             change_button(document.getElementById("run_button_10"), true);
//             change_button(document.getElementB

// %% [markdown]
// #### Monitorear las variables
//
// La función `println()` imprime en la consola del IDE de processing una línea seguida por un salto de línea. Esta función es muy útil cuando se debe monitorear el valor que tiene o adquiere una variable.

// %%
int x = 0;

void setup(){
    size(100, 50);
}

void draw(){
    println("el valor de X es: " + x);
    x++;
}
// Out:
// <div id="canvas_div_11">
//   <b>Sketch #11:</b><br/>
//   <canvas id="canvas_11"></canvas><br/>
// </div>
// <div id="controls_div_11">
//   <button id="run_button_11" onclick="startSketch('11');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_11" onclick="pauseSketch('11');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_11" onclick="setupSketch('11');">
//     setup()
//   </button>
//   <button id="draw_button_11" onclick="drawSketch('11');">
//     draw()
//   </button>
// </div>
// <b>Sketch #11 state:</b> <span id="state_11">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = 'int x = 0;\n\nvoid setup(){\n    size(100, 50);\n}\n\nvoid draw(){\n    println("el valor de X es: " + x);\n    x++;\n}';
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_11").innerHTML = e.toString();
//         document.getElementById("state_11").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_11", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_11").innerHTML = e.toString();
//             document.getElementById("state_11").style.color = "red";
//             processingInstance = new Processing("canvas_11", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_11").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_11").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("state_11").innerHTML = "Running...";
//                 document.getElementById("state_11").style.color = "green";
//             }
//             change_button(document.getElementById("run_button_11"), true);
//             change_button(document.getElementById("pause_button_11"), false);
//             change_button(document.getElementById("setup_button_11"),  true);
//             change_button(document.getElementById("draw_button_11"), true);
//         } else {
//             if (!has_error) {
//                 document.getElementById("state_11").innerHTML = "Done.";
//                 document.getElementById("state_11").style.color = "blue";
//             }
//             change_button(document.getElementById("run_button_11"), true);
//             change_button(document.getElementById("pause_button_11"), true);
//             change_button(document.getElementById("setup_
// el valor de X es: 0
// el valor de X es: 1
// el valor de X es: 2
// el valor de X es: 3
// el valor de X es: 4
// el valor de X es: 5
// el valor de X es: 6
// el valor de X es: 7
// el valor de X es: 8
// el valor de X es: 9
// el valor de X es: 10
// el valor de X es: 11
// el valor de X es: 12
// el valor de X es: 13
// el valor de X es: 14
// el valor de X es: 15
// el valor de X es: 16
// el valor de X es: 17
// el valor de X es: 18
// el valor de X es: 19
// el valor de X es: 20
// el valor de X es: 21
// el valor de X es: 22
// el valor de X es: 23
// el valor de X es: 24
// el valor de X es: 25
// el valor de X es: 26
// el valor de X es: 27
// el valor de X es: 28
// el valor de X es: 29
// el valor de X es: 30
// el valor de X es: 31
// el valor de X es: 32
// el valor de X es: 33
// el valor de X es: 34
// el valor de X es: 35
// el valor de X es: 36
// el valor de X es: 37
// el valor de X es: 38
// el valor de X es: 39
// el valor de X es: 40
// el valor de X es: 41
// el valor de X es: 42
// el valor de X es: 43
// el valor de X es: 44
// el valor de X es: 45
// el valor de X es: 46
// el valor de X es: 47
// el valor de X es: 48
// el valor de X es: 49
// el valor de X es: 50
// el valor de X es: 51
// el valor de X es: 52
// el valor de X es: 53
// el valor de X es: 54
// el valor de X es: 55
// el valor de X es: 56
// el valor de X es: 57
// el valor de X es: 58
// el valor de X es: 59
// el valor de X es: 60
// el valor de X es: 61
// el valor de X es: 62
// el valor de X es: 63
// el valor de X es: 64
// el valor de X es: 65
// el valor de X es: 66
// el valor de X es: 67
// el valor de X es: 68
// el valor de X es: 69
// el valor de X es: 70
// el valor de X es: 71
// el valor de X es: 72
// el valor de X es: 73
// el valor de X es: 74
// el valor de X es: 75
// el valor de X es: 76
// el valor de X es: 77
// el valor de X es: 78
// el valor de X es: 79
// el valor de X es: 80
// el valor de X es: 81
// el valor de X es: 82
// el valor de X es: 83
// el valor de X es: 84
// el valor de X es: 85
// el valor de X es: 86
// el valor de X es: 87
// el valor de X es: 88
// el valor de X es: 89
// el valor de X es: 90
// el valor de X es: 91
// el valor de X es: 92
// el valor de X es: 93
// el valor de X es: 94
// el valor de X es: 95
// el valor de X es: 96
// el valor de X es: 97
// el valor de X es: 98
// el valor de X es: 99
// el valor de X es: 100
// el valor de X es: 101
// el valor de X es: 102
// el valor de X es: 103
// el valor de X es: 104
// el valor de X es: 105
// el valor de X es: 106
// el valor de X es: 107
// el valor de X es: 108
// el valor de X es: 109
// el valor de X es: 110
// el valor de X es: 111
// el valor de X es: 112
// el valor de X es: 113
// el valor de X es: 114
// el valor de X es: 115
// el valor de X es: 116
// el valor de X es: 117
// el valor de X es: 118
// el valor de X es: 119
// el valor de X es: 120
// el valor de X es: 121
// el valor de X es: 122
// el valor de X es: 123
// el valor de X es: 124
// el valor de X es: 125
// el valor de X es: 126
// el valor de X es: 127
// el valor de X es: 128
// el valor de X es: 129
// el valor de X es: 130
// el valor de X es: 131
// el valor de X es: 132
// el valor de X es: 133
// el valor de X es: 134
// el valor de X es: 135
// el valor de X es: 136
// el valor de X es: 137
// el valor de X es: 138
// el valor de X es: 139
// el valor de X es: 140
// el valor de X es: 141
// el valor de X es: 142
// el valor de X es: 143
// el valor de X es: 144
// el valor de X es: 145
// el valor de X es: 146
// el valor de X es: 147
// el valor de X es: 148
// el valor de X es: 149
// el valor de X es: 150
// el valor de X es: 151
// el valor de X es: 152
// el valor de X es: 153
// el valor de X es: 154
// el valor de X es: 155
// el valor de X es: 156
// el valor de X es: 157
// el valor de X es: 158
// el valor de X es: 159
// el valor de X es: 160
// el valor de X es: 161
// el valor de X es: 162
// el valor de X es: 163
// el valor de X es: 164
// el valor de X es: 165
// el valor de X es: 166
// el valor de X es: 167
// el valor de X es: 168
// el valor de X es: 169
// el valor de X es: 170
// el valor de X es: 171
// el valor de X es: 172
// el valor de X es: 173
// el valor de X es: 174
// el valor de X es: 175
// el valor de X es: 176
// el valor de X es: 177
// el valor de X es: 178
// el valor de X es: 179
// el valor de X es: 180
// el valor de X es: 181
// el valor de X es: 182
// el valor de X es: 183
// el valor de X es: 184
// el valor de X es: 185
// el valor de X es: 186
// el valor de X es: 187
// el valor de X es: 188
// el valor de X es: 189
// el valor de X es: 190
// el valor de X es: 191
// el valor de X es: 192
// el valor de X es: 193
// el valor de X es: 194
// el valor de X es: 195
// el valor de X es: 196
// el valor de X es: 197
// el valor de X es: 198
// el valor de X es: 199
// el valor de X es: 200
// el valor de X es: 201
// el valor de X es: 202
// el valor de X es: 203
// el valor de X es: 204
// el valor de X es: 205
// el valor de X es: 206
// el valor de X es: 207
// el valor de X es: 208
// el valor de X es: 209
// el valor de X es: 210
// el valor de X es: 211
// el valor de X es: 212
// el valor de X es: 213
// el valor de X es: 214
// el valor de X es: 215
// el valor de X es: 216
// el valor de X es: 217
// el valor de X es: 218
// el valor de X es: 219
// el valor de X es: 220
// el valor de X es: 221
// el valor de X es: 222
// el valor de X es: 223
// el valor de X es: 224
// el valor de X es: 225
// el valor de X es: 226
// el valor de X es: 227
// el valor de X es: 228
// el valor de X es: 229
// el valor de X es: 230
// el valor de X es: 231
// el valor de X es: 232
// el valor de X es: 233
// el valor de X es: 234
// el valor de X es: 235
// el valor de X es: 236
// el valor de X es: 237
// el valor de X es: 238
// el valor de X es: 239
// el valor de X es: 240
// el valor de X es: 241
// el valor de X es: 242
// el valor de X es: 243
// el valor de X es: 244
// el valor de X es: 245
// el valor de X es: 246
// el valor de X es: 247
// el valor de X es: 248
// el valor de X es: 249
// el valor de X es: 250
// el valor de X es: 251
// el valor de X es: 252
// el valor de X es: 253
// el valor de X es: 254
// el valor de X es: 255
// el valor de X es: 256
// el valor de X es: 257
// el valor de X es: 258
// el valor de X es: 259
// el valor de X es: 260
// el valor de X es: 261
// el valor de X es: 262
// el valor de X es: 263
// el valor de X es: 264
// el valor de X es: 265
// el valor de X es: 266
// el valor de X es: 267
// el valor de X es: 268
// el valor de X es: 269
// el valor de X es: 270
// el valor de X es: 271
// el valor de X es: 272
// el valor de X es: 273
// el valor de X es: 274
// el valor de X es: 275
// el valor de X es: 276
// el valor de X es: 277
// el valor de X es: 278
// el valor de X es: 279
// el valor de X es: 280
// el valor de X es: 281
// el valor de X es: 282
// el valor de X es: 283
// el valor de X es: 284
// el valor de X es: 285
// el valor de X es: 286
// el valor de X es: 287
// el valor de X es: 288
// el valor de X es: 289
// el valor de X es: 290
// el valor de X es: 291
// el valor de X es: 292
// el valor de X es: 293
// el valor de X es: 294
// el valor de X es: 295
// el valor de X es: 296
// el valor de X es: 297
// el valor de X es: 298
// el valor de X es: 299
// el valor de X es: 300
// el valor de X es: 301
// el valor de X es: 302
// el valor de X es: 303
// el valor de X es: 304
// el valor de X es: 305
// el valor de X es: 306
// el valor de X es: 307
// el valor de X es: 308
// el valor de X es: 309
// el valor de X es: 310
// el valor de X es: 311
// el valor de X es: 312
// el valor de X es: 313
// el valor de X es: 314
// el valor de X es: 315
// el valor de X es: 316
// el valor de X es: 317
// el valor de X es: 318
// el valor de X es: 319
// el valor de X es: 320
// el valor de X es: 321
// el valor de X es: 322
// el valor de X es: 323
// el valor de X es: 324
// el valor de X es: 325
// el valor de X es: 326
// el valor de X es: 327
// el valor de X es: 328
// el valor de X es: 329
// el valor de X es: 330
// el valor de X es: 331
// el valor de X es: 332
// el valor de X es: 333
// el valor de X es: 334
// el valor de X es: 335
// el valor de X es: 336
// el valor de X es: 337
// el valor de X es: 338
// el valor de X es: 339
// el valor de X es: 340
// el valor de X es: 341
// el valor de X es: 342
// el valor de X es: 343
// el valor de X es: 344
// el valor de X es: 345
// el valor de X es: 346
// el valor de X es: 347
// el valor de X es: 348
// el valor de X es: 349
// el valor de X es: 350
// el valor de X es: 351
// el valor de X es: 352
// el valor de X es: 353
// el valor de X es: 354
// el valor de X es: 355
// el valor de X es: 356
// el valor de X es: 357
// el valor de X es: 358
// el valor de X es: 359
// el valor de X es: 360
// el valor de X es: 361
// el valor de X es: 362
// el valor de X es: 363
// el valor de X es: 364
// el valor de X es: 365
// el valor de X es: 366
// el valor de X es: 367
// el valor de X es: 368
// el valor de X es: 369
// el valor de X es: 370
// el valor de X es: 371
// el valor de X es: 372
// el valor de X es: 373
// el valor de X es: 374
// el valor de X es: 375
// el valor de X es: 376
// el valor de X es: 377
// el valor de X es: 378
// el valor de X es: 379
// el valor de X es: 380
// el valor de X es: 381
// el valor de X es: 382
// el valor de X es: 383
// el valor de X es: 384
// el valor de X es: 385
// el valor de X es: 386
// el valor de X es: 387
// el valor de X es: 388
// el valor de X es: 389
// el valor de X es: 390
// el valor de X es: 391
// el valor de X es: 392
// el valor de X es: 393
// el valor de X es: 394
// el valor de X es: 395
// el valor de X es: 396
// el valor de X es: 397
// el valor de X es: 398
// el valor de X es: 399
// el valor de X es: 400
// el valor de X es: 401
// el valor de X es: 402
// el valor de X es: 403
// el valor de X es: 404
// el valor de X es: 405
// el valor de X es: 406
// el valor de X es: 407
// el valor de X es: 408
// el valor de X es: 409
// el valor de X es: 410
// el valor de X es: 411
// el valor de X es: 412
// el valor de X es: 413
// el valor de X es: 414
// el valor de X es: 415
// el valor de X es: 416
// el valor de X es: 417
// el valor de X es: 418
// el valor de X es: 419
// el valor de X es: 420
// el valor de X es: 421
// el valor de X es: 422
// el valor de X es: 423
// el valor de X es: 424
// el valor de X es: 425
// el valor de X es: 426
// el valor de X es: 427
// el valor de X es: 428
// el valor de X es: 429
// el valor de X es: 430
// el valor de X es: 431
// el valor de X es: 432
// el valor de X es: 433
// el valor de X es: 434
// el valor de X es: 435
// el valor de X es: 436
// el valor de X es: 437
// el valor de X es: 438
// el valor de X es: 439
// el valor de X es: 440
// el valor de X es: 441
// el valor de X es: 442
// el valor de X es: 443
// el valor de X es: 444
// el valor de X es: 445
// el valor de X es: 446
// el valor de X es: 447
// el valor de X es: 448
// el valor de X es: 449
// el valor de X es: 450
// el valor de X es: 451
// el valor de X es: 452
// el valor de X es: 453
// el valor de X es: 454
// el valor de X es: 455
// el valor de X es: 456
// el valor de X es: 457
// el valor de X es: 458
// el valor de X es: 459
// el valor de X es: 460
// el valor de X es: 461
// el valor de X es: 462
// el valor de X es: 463
// el valor de X es: 464
// el valor de X es: 465
// el valor de X es: 466
// el valor de X es: 467
// el valor de X es: 468
// el valor de X es: 469
// el valor de X es: 470
// el valor de X es: 471
// el valor de X es: 472
// el valor de X es: 473
// el valor de X es: 474
// el valor de X es: 475
// el valor de X es: 476
// el valor de X es: 477
// el valor de X es: 478
// el valor de X es: 479
// el valor de X es: 480
// el valor de X es: 481
// el valor de X es: 482
// el valor de X es: 483
// el valor de X es: 484
// el valor de X es: 485
// el valor de X es: 486
// el valor de X es: 487
// el valor de X es: 488
// el valor de X es: 489
// el valor de X es: 490
// el valor de X es: 491
// el valor de X es: 492
// el valor de X es: 493
// el valor de X es: 494
// el valor de X es: 495
// el valor de X es: 496
// el valor de X es: 497
// el valor de X es: 498
// el valor de X es: 499
// el valor de X es: 500
// el valor de X es: 501
// el valor de X es: 502
// el valor de X es: 503
// el valor de X es: 504
// el valor de X es: 505
// el valor de X es: 506
// el valor de X es: 507
// el valor de X es: 508
// el valor de X es: 509
// el valor de X es: 510
// el valor de X es: 511
// el valor de X es: 512
// el valor de X es: 513
// el valor de X es: 514
// el valor de X es: 515
// el valor de X es: 516
// el valor de X es: 517
// el valor de X es: 518
// el valor de X es: 519
// el valor de X es: 520
// el valor de X es: 521
// el valor de X es: 522
// el valor de X es: 523
// el valor de X es: 524
// el valor de X es: 525
// el valor de X es: 526
// el valor de X es: 527
// el valor de X es: 528
// el valor de X es: 529
// el valor de X es: 530
// el valor de X es: 531
// el valor de X es: 532
// el valor de X es: 533
// el valor de X es: 534
// el valor de X es: 535
// el valor de X es: 536
// el valor de X es: 537
// el valor de X es: 538
// el valor de X es: 539
// el valor de X es: 540
// el valor de X es: 541
// el valor de X es: 542
// el valor de X es: 543
// el valor de X es: 544
// el valor de X es: 545
// el valor de X es: 546
// el valor de X es: 547
// el valor de X es: 548
// el valor de X es: 549
// el valor de X es: 550
// el valor de X es: 551
// el valor de X es: 552
// el valor de X es: 553
// el valor de X es: 554
// el valor de X es: 555
// el valor de X es: 556
// el valor de X es: 557
// el valor de X es: 558
// el valor de X es: 559
// el valor de X es: 560
// el valor de X es: 561
// el valor de X es: 562
// el valor de X es: 563
// el valor de X es: 564
// el valor de X es: 565
// el valor de X es: 566
// el valor de X es: 567
// el valor de X es: 568
// el valor de X es: 569
// el valor de X es: 570
// el valor de X es: 571
// el valor de X es: 572
// el valor de X es: 573
// el valor de X es: 574
// el valor de X es: 575
// el valor de X es: 576
// el valor de X es: 577
// el valor de X es: 578
// el valor de X es: 579
// el valor de X es: 580
// el valor de X es: 581
// el valor de X es: 582
// el valor de X es: 583
// el valor de X es: 584
// el valor de X es: 585
// el valor de X es: 586
// el valor de X es: 587
// el valor de X es: 588
// el valor de X es: 589
// el valor de X es: 590
// el valor de X es: 591
// el valor de X es: 592
// el valor de X es: 593
// el valor de X es: 594
// el valor de X es: 595
// el valor de X es: 596
// el valor de X es: 597
// el valor de X es: 598
// el valor de X es: 599
// el valor de X es: 600
// el valor de X es: 601
// el valor de X es: 602
// el valor de X es: 603
// el valor de X es: 604
// el valor de X es: 605
// el valor de X es: 606
// el valor de X es: 607
// el valor de X es: 608
// el valor de X es: 609
// el valor de X es: 610
// el valor de X es: 611
// el valor de X es: 612
// el valor de X es: 613
// el valor de X es: 614
// el valor de X es: 615
// el valor de X es: 616
// el valor de X es: 617
// el valor de X es: 618
// el valor de X es: 619
// el valor de X es: 620
// el valor de X es: 621
// el valor de X es: 622
// el valor de X es: 623
// el valor de X es: 624
// el valor de X es: 625
// el valor de X es: 626
// el valor de X es: 627
// el valor de X es: 628
// el valor de X es: 629
// el valor de X es: 630
// el valor de X es: 631
// el valor de X es: 632
// el valor de X es: 633
// el valor de X es: 634
// el valor de X es: 635
// el valor de X es: 636
// el valor de X es: 637
// el valor de X es: 638
// el valor de X es: 639
// el valor de X es: 640
// el valor de X es: 641
// el valor de X es: 642
// el valor de X es: 643
// el valor de X es: 644
// el valor de X es: 645
// el valor de X es: 646
// el valor de X es: 647
// el valor de X es: 648
// el valor de X es: 649
// el valor de X es: 650
// el valor de X es: 651
// el valor de X es: 652
// el valor de X es: 653
// el valor de X es: 654
// el valor de X es: 655
// el valor de X es: 656
// el valor de X es: 657
// el valor de X es: 658
// el valor de X es: 659
// el valor de X es: 660
// el valor de X es: 661
// el valor de X es: 662
// el valor de X es: 663
// el valor de X es: 664
// el valor de X es: 665
// el valor de X es: 666
// el valor de X es: 667
// el valor de X es: 668
// el valor de X es: 669
// el valor de X es: 670
// el valor de X es: 671
// el valor de X es: 672
// el valor de X es: 673
// el valor de X es: 674
// el valor de X es: 675
// el valor de X es: 676
// el valor de X es: 677
// el valor de X es: 678
// el valor de X es: 679
// el valor de X es: 680
// el valor de X es: 681
// el valor de X es: 682
// el valor de X es: 683
// el valor de X es: 684
// el valor de X es: 685
// el valor de X es: 686
// el valor de X es: 687
// el valor de X es: 688
// el valor de X es: 689
// el valor de X es: 690
// el valor de X es: 691
// el valor de X es: 692
// el valor de X es: 693
// el valor de X es: 694
// el valor de X es: 695
// el valor de X es: 696
// el valor de X es: 697
// el valor de X es: 698
// el valor de X es: 699
// el valor de X es: 700
// el valor de X es: 701
// el valor de X es: 702
// el valor de X es: 703
// el valor de X es: 704
// el valor de X es: 705
// el valor de X es: 706
// el valor de X es: 707
// el valor de X es: 708
// el valor de X es: 709
// el valor de X es: 710
// el valor de X es: 711
// el valor de X es: 712
// el valor de X es: 713
// el valor de X es: 714
// el valor de X es: 715
// el valor de X es: 716
// el valor de X es: 717
// el valor de X es: 718
// el valor de X es: 719
// el valor de X es: 720
// el valor de X es: 721
// el valor de X es: 722
// el valor de X es: 723
// el valor de X es: 724
// el valor de X es: 725
// el valor de X es: 726
// el valor de X es: 727
// el valor de X es: 728
// el valor de X es: 729
// el valor de X es: 730
// el valor de X es: 731
// el valor de X es: 732
// el valor de X es: 733
// el valor de X es: 734
// el valor de X es: 735
// el valor de X es: 736
// el valor de X es: 737
// el valor de X es: 738
// el valor de X es: 739
// el valor de X es: 740
// el valor de X es: 741
// el valor de X es: 742
// el valor de X es: 743
// el valor de X es: 744
// el valor de X es: 745
// el valor de X es: 746
// el valor de X es: 747
// el valor de X es: 748
// el valor de X es: 749
// el valor de X es: 750
// el valor de X es: 751
// el valor de X es: 752
// el valor de X es: 753
// el valor de X es: 754
// el valor de X es: 755
// el valor de X es: 756
// el valor de X es: 757
// el valor de X es: 758
// el valor de X es: 759
// el valor de X es: 760
// el valor de X es: 761
// el valor de X es: 762
// el valor de X es: 763
// el valor de X es: 764
// el valor de X es: 765
// el valor de X es: 766
// el valor de X es: 767
// el valor de X es: 768
// el valor de X es: 769
// el valor de X es: 770
// el valor de X es: 771
// el valor de X es: 772
// el valor de X es: 773
// el valor de X es: 774
// el valor de X es: 775
// el valor de X es: 776
// el valor de X es: 777
// el valor de X es: 778
// el valor de X es: 779
// el valor de X es: 780
// el valor de X es: 781
// el valor de X es: 782
// el valor de X es: 783
// el valor de X es: 784
// el valor de X es: 785
// el valor de X es: 786
// el valor de X es: 787
// el valor de X es: 788
// el valor de X es: 789
// el valor de X es: 790
// el valor de X es: 791
// el valor de X es: 792
// el valor de X es: 793
// el valor de X es: 794
// el valor de X es: 795
// el valor de X es: 796
// el valor de X es: 797
// el valor de X es: 798
// el valor de X es: 799
// el valor de X es: 800
// el valor de X es: 801
// el valor de X es: 802
// el valor de X es: 803
// el valor de X es: 804
// el valor de X es: 805
// el valor de X es: 806
// el valor de X es: 807
// el valor de X es: 808

// %% [markdown]
// ## Actividad 3: Dragon rojo
//
// Observa con detenimiento el siguiente sketch y su ejecución. Responde:
//
// 1. Agrega una línea que permita monitorear la variable tiempo y explica cómo afecta al sketch esta variable ¿qué pasa si se elimina? y ¿si se aumenta el incremento?. ¿Cómo puedes simplificar la escritura de la línea en la que se incrementa la variable en uno?
// 2. Lee hacerca de la variable `frameRate` y la constrante `PI` luego lee hacerca de _curvas sinusoidades_. Ahora intenta explicar el cambio de las variables `rojo` y `diametro`.
// 3. ¿Podría reemplazar la elipse con un rectángulo que rote lentamente a medida que se mueva? Inténtalo. _sugerencia: lee sobre las funciones de `rotate` y `rectMode`_.

// %%
int rojo = 255;
int tiempo = 0;
int diametro = 50;
 
void setup() {
  size(400, 400);
}

void draw() {
  tiempo = tiempo + 1;     
  rojo = int(128 * (1 + sin(tiempo * 2 * PI / frameRate / 20))); 
  diametro = int(50 * (1 + sin( tiempo * 2 * PI / frameRate / 5))); // Modifica el diametro del circulo con el paso del tiempo
  
  noStroke();             
  fill(rojo, 0, 0, 50);  // Añade un 50% de transparencia al color
  ellipse(mouseX, mouseY, diametro, diametro); 
}
// Out:
// <div id="canvas_div_3">
//   <b>Sketch #3:</b><br/>
//   <canvas id="canvas_3"></canvas><br/>
// </div>
// <div id="controls_div_3">
//   <button id="run_button_3" onclick="startSketch('3');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_3" onclick="pauseSketch('3');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_3" onclick="setupSketch('3');">
//     setup()
//   </button>
//   <button id="draw_button_3" onclick="drawSketch('3');">
//     draw()
//   </button>
// </div>
// <b>Sketch #3 state:</b> <span id="state_3">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = 'int rojo = 255;\nint tiempo = 0;\nint diametro = 50;\n \nvoid setup() {\n  size(400, 400);\n}\n\nvoid draw() {\n  tiempo = tiempo + 1;     \n  rojo = int(128 * (1 + sin(tiempo * 2 * PI / frameRate / 20))); \n  diametro = int(50 * (1 + sin( tiempo * 2 * PI / frameRate / 5))); // Modifica el diametro del circulo con el paso del tiempo\n  \n  noStroke();             \n  fill(rojo, 0, 0, 50);  // Añade un 50% de transparencia al color\n  ellipse(mouseX, mouseY, diametro, diametro); \n}';
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_3").innerHTML = e.toString();
//         document.getElementById("state_3").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_3", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_3").innerHTML = e.toString();
//             document.getElementById("state_3").style.color = "red";
//             processingInstance = new Processing("canvas_3", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_3").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_3").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("state_3").innerHTML = "Running...";
//                 document.getElementById("state_3").style.color = "green";
//             }
//             change_button(document.getElementById("run_button_3"), true);
//             change_button(document.getElementById("pause_button_3"), false);
//             change_button(document.getElementById("setup_button_3"),  true);
//             change_button(document.getElementById("draw_button_3"), true);
//         } else {
//             if (!has_error) {
//                 document.getEle

// %% [markdown]
// ## Actividad 4: Segundero análogo
//
// <img src="./images/analog_sec.gif" width="200">
//
// En esta actividad crearás el segundero de un relog análogo.
//
// ### ¿Qué necesitas saber?
// 1. El segundero de un relog análogo recorre $2\pi$ radianes en 60 segundos.
// 2. Las coordenadas de un punto en un plano pueden darse en forma polar tal como se ve en la siguiente figura
//
// <img src="./images/polar_coords.png">
//
// tomando un punto ($O$) como origen de la rotación, la abscisa de un punto $P$ sobre la circunferencia esta dada por el  coseno del ángulo que se mide desde el origen de la rotación $O$ hasta el punto $P$ ($\cos \alpha$) mientras que la ordenada de $P$ esta dada por el seno del mismo ángulo ($\sin \alpha$).
//
// Cuando - como en el caso de processing - el origen de la rotación no corresponde con origen del plano coordenado en necesario tener en cuenta la ubicación del origen (desplazado) de la rotación y las coordenadas del punto $P$ estan dadas como sigue
//
// $$
// (D + A \times \cos (\alpha), D + A \times \sin (\alpha))
// $$
//
// donde $D$ es la distancia del  desde el origen del plano, $A$ es la longitud desde el nuevo origen al punto que se esta definiendo y $\alpha$ es el ángulo sobre el cual se encuentra el punto.
//
// <img src="./images/analog_sec_coords.png">
//
// ### ¿Qué debes hacer?
// Definiendo no más de cuatro variables (el ángulo, heigth, width o las coordendas del centro del reloj y el diámetro o radio de la circunferencia) debes construir la manecilla del segundero de un relog análogo, ésta debe empezar a moverse desde $-\frac{\pi}{2}$ (la posición de la hora 12) en el sentido de las manecillas del reloj tal como se observa en la animación de arriba.
//
// Agrega ``saveFrame("frames/####.tif");`` como última línea del bloque ``draw`` de tu sketch, esto creará una carpeta _frames_ dentro de la carpeta del sketch, luego abre en creador de películas desde el menú _Herramientas_ del IDE de processing y carga ese directorio para crear un vídeo de la ejecución de tu sketch.
